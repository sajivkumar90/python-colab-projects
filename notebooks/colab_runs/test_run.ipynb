# %% [markdown]
# <a href="https://colab.research.google.com/github/sajivkumar90/python-colab-projects/blob/main/notebooks/colab_runs/test_run.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Colab + GitHub pipeline is working!")
# Out:
# Colab + GitHub pipeline is working!
